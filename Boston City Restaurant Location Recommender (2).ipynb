# %% [markdown]
# # <font color=red>Capstone Week 4- Final Assignment</font>

# %% [markdown]
# ## <font color=blue>Problem: </font> Where to open an Italian Restaurant in Boston?
# ### <font color=blue>Writer: </font> Deniz Aytemiz

# %% [markdown]
# ## <font color=red>Introduction/Business Problem: </font>
#    __In this project, the best location for opening an Italian Restaurant in Boston will be examined. The criterias will be low rate of crime, popularity of the area, number of other Italian restaurants in the area, housing for rent prices and rankings of the Italian restaurants in that area. By area I mean locations determined by distinct postal codes. The areas will be segmented according to their competitiveness, safeness, cheapness and popularity. This analysis  might be useful for those want to open Italian Restaurant in Boston and want to know where would be most advantegous.__

# %% [markdown]
# ## <font color=red>Data: </font>
# __The Foursquare data is used for observing number of Italian Restaurants in specific areas(postal codes) in addition to their ratings. I used trending venue API request of Foursquare for an indication of popularity of the areas, however query returned no trending venue result. Therefore to gain insight on the popularity of the area, I examine the the number of tips for venues in a location. The more entries, the more popularity is indicated. In addition to Foursquare data from Boston's goverment website, I  retrieved a dataset on the prices of houses as well as a dataset about the crimes in the city. These datasets are analyzed for crime rates and housing prices of the postal code areas.__

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 8.9 MB/s  eta 0:00:01
# Collecting branca
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=0f37374cb5d0ef49fddcf069c2de890b96c296beb4fa6da2e328ef5c32ee9c0e
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.5.0
# Folium installed
# Libraries imported.

# %% [markdown]
# ## 1st data set from boston.gov, the housing prices are given.

# %%
other_path = "https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/695a8596-5458-442b-a017-7cd72471aade/download/fy19fullpropassess.csv"
df = pd.read_csv(other_path, header=0)
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (15,60) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#          PID        CM_ID     GIS_ID ST_NUM ST_NAME ST_NAME_SUF UNIT_NUM  \
# 0  502550008  502550000.0  502550000     87  BEACON          ST      2-F
# 1  502550010  502550000.0  502550000     87  BEACON          ST      2-R
# 2  502550012  502550000.0  502550000     87  BEACON          ST      3-F
# 3  502550014  502550000.0  502550000     87  BEACON          ST      3-R
# 4  502550016  502550000.0  502550000     87  BEACON          ST        4
#
#    ZIPCODE  PTYPE  LU  ... U_BTH_STYLE2 U_BTH_STYLE3 U_KITCH_TYPE  \
# 0   2108.0    102  CD  ...            M          NaN            O
# 1   2108.0    102  CD  ...          NaN          NaN            O
# 2   2108.0    102  CD  ...            S          NaN            O
# 3   2108.0    102  CD  ...          NaN          NaN            O
# 4   2108.0    102  CD  ...            M            M            O
#
#   U_KITCH_STYLE U_HEAT_TYP U_AC  U_FPLACE  U_INT_FIN  U_INT_CND  U_VIEW
# 0             M          W    N       1.0          N          G       A
# 1             S          W    N       1.0          N          A       A
# 2             M          W    N       1.0          N          A       G
# 3             N          W    N       1.0          S          A       G
# 4             L          W    C       2.0          N          E       G
#
# [5 rows x 75 columns]

# %% [markdown]
# ## The needed columns are taken, others are dropped. This dataframe will be used later on.

# %%
data_price = df[['ZIPCODE','ST_NAME','AV_TOTAL']]
data_price.head()
# Out:
#    ZIPCODE ST_NAME  AV_TOTAL
# 0   2108.0  BEACON    878200
# 1   2108.0  BEACON    817600
# 2   2108.0  BEACON    849500
# 3   2108.0  BEACON    734400
# 4   2108.0  BEACON   2162300

# %%
data_price=data_price.head(100)

# %%
data_price.shape
# Out:
# (100, 3)

# %% [markdown]
# ## 2nd datafarem from boston.gov, this dataset gives crime incidents in Boston

# %%
other_path = "https://data.boston.gov/dataset/6220d948-eae2-4e4b-8723-2dc8e67722a3/resource/12cb3883-56f5-47de-afa5-3b1cf61b257b/download/tmpcq9l0azx.csv"
df_crime = pd.read_csv(other_path, header=0)
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,2,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_crime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP        OFFENSE_DESCRIPTION  \
# 0       TESTTEST2           423                NaN       ASSAULT - AGGRAVATED
# 1       S97333701          3301                NaN             VERBAL DISPUTE
# 2       S47513131          2647                NaN  THREATS TO DO BODILY HARM
# 3       I92102201          3301                NaN             VERBAL DISPUTE
# 4       I92097173          3115                NaN         INVESTIGATE PERSON
#
#    DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0  External                       0  2019-10-16 00:00:00  2019     10
# 1        C6            915        0  2020-07-18 14:34:00  2020      7
# 2       E18            530        0  2020-06-24 10:15:00  2020      6
# 3       E13            583        0  2019-12-20 03:08:00  2019     12
# 4       C11            355        0  2019-10-23 00:00:00  2019     10
#
#   DAY_OF_WEEK  HOUR UCR_PART          STREET        Lat       Long  \
# 0   Wednesday     0      NaN    RIVERVIEW DR        NaN        NaN
# 1    Saturday    14      NaN  MARY BOYLE WAY  42.330813 -71.051368
# 2   Wednesday    10      NaN    READVILLE ST  42.239491 -71.135954
# 3      Friday     3      NaN          DAY ST  42.325122 -71.107779
# 4   Wednesday     0      NaN       GIBSON ST  42.297555 -71.059709
#
#                       Location
# 0     (0.00000000, 0.00000000)
# 1  (42.33081300, -71.05136800)
# 2  (42.23949100, -71.13595400)
# 3  (42.32512200, -71.10777900)
# 4  (42.29755500, -71.05970900)

# %% [markdown]
# ## Columns needed are retrieved, others dropped

# %%
data_crime = df_crime[['DISTRICT','STREET','Lat','Long']]
data_crime.head()
# Out:
#    DISTRICT          STREET        Lat       Long
# 0  External    RIVERVIEW DR        NaN        NaN
# 1        C6  MARY BOYLE WAY  42.330813 -71.051368
# 2       E18    READVILLE ST  42.239491 -71.135954
# 3       E13          DAY ST  42.325122 -71.107779
# 4       C11       GIBSON ST  42.297555 -71.059709

# %%
data_crime=data_crime.head(100)

# %%
data_crime.shape
# Out:
# (100, 4)

# %% [markdown]
# ## The place of crime is given as District, we will convert this to postal codes later on.

# %%
data_crime.DISTRICT.unique()
# Out:
# array(['External', 'C6', 'E18', 'E13', 'C11', 'D14', 'B2', 'A15', nan,
#        'E5', 'A1', 'B3', 'A7', 'D4'], dtype=object)

# %%
data_crime=data_crime.dropna(subset=["DISTRICT"], axis=0)

# %%
data_crime
# Out:
#     DISTRICT          STREET        Lat       Long
# 0   External    RIVERVIEW DR        NaN        NaN
# 1         C6  MARY BOYLE WAY  42.330813 -71.051368
# 2        E18    READVILLE ST  42.239491 -71.135954
# 3        E13          DAY ST  42.325122 -71.107779
# 4        C11       GIBSON ST  42.297555 -71.059709
# ..       ...             ...        ...        ...
# 95       C11     COLUMBIA RD  42.309692 -71.072859
# 96       C11       LESLIE ST  42.295147 -71.058608
# 97        A7       LONDON ST  42.375684 -71.036249
# 98        B2       CEDRIC ST  42.325714 -71.071317
# 99        B3    WALK HILL ST  42.280827 -71.097547
#
# [99 rows x 4 columns]

# %% [markdown]
# ## External entries in District column is dropped

# %%
data_crime = data_crime[data_crime.DISTRICT != 'External']

# %%
data_crime
# Out:
#    DISTRICT          STREET        Lat       Long
# 1        C6  MARY BOYLE WAY  42.330813 -71.051368
# 2       E18    READVILLE ST  42.239491 -71.135954
# 3       E13          DAY ST  42.325122 -71.107779
# 4       C11       GIBSON ST  42.297555 -71.059709
# 5       D14       BROOKS ST  42.355120 -71.162678
# ..      ...             ...        ...        ...
# 95      C11     COLUMBIA RD  42.309692 -71.072859
# 96      C11       LESLIE ST  42.295147 -71.058608
# 97       A7       LONDON ST  42.375684 -71.036249
# 98       B2       CEDRIC ST  42.325714 -71.071317
# 99       B3    WALK HILL ST  42.280827 -71.097547
#
# [98 rows x 4 columns]

# %% [markdown]
# ## Instead of district, the place is replaced with postal codes

# %%
data_crime['DISTRICT'] = data_crime['DISTRICT'].replace(['C6','E18','E13','C11','D14','B2','A15','E5','A1','B3','A7','D4'],['02127','02136','02130','02122','02135','02119','02114','02132','02114','02124','02128','02116'])
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
data_crime
# Out:
#    DISTRICT          STREET        Lat       Long
# 1     02127  MARY BOYLE WAY  42.330813 -71.051368
# 2     02136    READVILLE ST  42.239491 -71.135954
# 3     02130          DAY ST  42.325122 -71.107779
# 4     02122       GIBSON ST  42.297555 -71.059709
# 5     02135       BROOKS ST  42.355120 -71.162678
# ..      ...             ...        ...        ...
# 95    02122     COLUMBIA RD  42.309692 -71.072859
# 96    02122       LESLIE ST  42.295147 -71.058608
# 97    02128       LONDON ST  42.375684 -71.036249
# 98    02119       CEDRIC ST  42.325714 -71.071317
# 99    02124    WALK HILL ST  42.280827 -71.097547
#
# [98 rows x 4 columns]

# %% [markdown]
# ## Which district has how many crime incidents recored is observed

# %%
data_crime['DISTRICT'].value_counts()
# Out:
# 02124    13
# 02114    13
# 02119    12
# 02128    12
# 02130    10
# 02136     9
# 02122     8
# 02135     7
# 02127     6
# 02116     4
# 02132     4
# Name: DISTRICT, dtype: int64

# %%
new_data = {'postalCode':  ['02124', '02119','02128','02114','02130','02136','02122','02135' ,'02127','02118','02132','02120'],
        'number of Crimes': [13, 12,12,10,10,9,8,7,6,4,4,3]
        }
df_crime = pd.DataFrame (new_data, columns = ['postalCode','number of Crimes'])

df_crime
# Out:
#    postalCode  number of Crimes
# 0       02124                13
# 1       02119                12
# 2       02128                12
# 3       02114                10
# 4       02130                10
# 5       02136                 9
# 6       02122                 8
# 7       02135                 7
# 8       02127                 6
# 9       02118                 4
# 10      02132                 4
# 11      02120                 3

# %%
data_price
# Out:
#     ZIPCODE    ST_NAME  AV_TOTAL
# 0    2108.0     BEACON    878200
# 1    2108.0     BEACON    817600
# 2    2108.0     BEACON    849500
# 3    2108.0     BEACON    734400
# 4    2108.0     BEACON   2162300
# ..      ...        ...       ...
# 95   2128.0  PRINCETON    658300
# 96   2128.0  PRINCETON    615030
# 97   2128.0  PRINCETON    615030
# 98   2128.0  PRINCETON    663800
# 99   2128.0  PRINCETON    559000
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Street names in house price dataset are replaced with postal codes

# %%
data_price.ST_NAME.unique()
# Out:
# array(['BEACON', 'BEAVER', 'BRIMMER', 'PUTNAM', 'LEXINGTON', 'PRESCOTT',
#        'PRINCETON'], dtype=object)

# %%
data_price['ST_NAME'] = data_price['ST_NAME'].replace(['BEACON','BEAVER','BRIMMER','PUTNAM','LEXINGTON','PRESCOTT','PRINCETON'],['02108 ','02108','02108','02110','02128','02136','02128'])

# %%
data_price
# Out:
#     ZIPCODE ST_NAME  AV_TOTAL
# 0    2108.0  02108     878200
# 1    2108.0  02108     817600
# 2    2108.0  02108     849500
# 3    2108.0  02108     734400
# 4    2108.0  02108    2162300
# ..      ...     ...       ...
# 95   2128.0   02128    658300
# 96   2128.0   02128    615030
# 97   2128.0   02128    615030
# 98   2128.0   02128    663800
# 99   2128.0   02128    559000
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Foursquare data

# %%
CLIENT_ID = 'AWYBVOQRZDAUENRKYQ1UG1K3IBFBHYCUCXSUIJFBA4VSR4LE' # your Foursquare ID
CLIENT_SECRET = 'J4RO3S4IZA3HYTX2EFNCQEESQDIFLOMCGSIGURV2RRIZCKYO' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: AWYBVOQRZDAUENRKYQ1UG1K3IBFBHYCUCXSUIJFBA4VSR4LE
# CLIENT_SECRET:J4RO3S4IZA3HYTX2EFNCQEESQDIFLOMCGSIGURV2RRIZCKYO

# %% [markdown]
# ## latitude and longitude values of Boston

# %%
latitude=42.361145
longitude=-71.057083
radius=500

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=AWYBVOQRZDAUENRKYQ1UG1K3IBFBHYCUCXSUIJFBA4VSR4LE&client_secret=J4RO3S4IZA3HYTX2EFNCQEESQDIFLOMCGSIGURV2RRIZCKYO&ll=42.361145,-71.057083&v=20180604&radius=500&limit=100'

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
import requests
results = requests.get(url).json()
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4ba50617f964a520f1d138e3',
#   'name': 'North End Park',
#   'location': {'address': 'Cross St.',
#    'crossStreet': 'btwn North & Sudbury',
#    'lat': 42.36248823184806,
#    'lng': -71.05647696102726,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 42.36248823184806,
#      'lng': -71.05647696102726}],
#    'distance': 157,
#    'postalCode': '02113',
#    'cc': 'US',
#    'city': 'Boston',
#    'state': 'MA',
#    'country': 'United States',
#    'formattedAddress': ['Cross St. (btwn North & Sudbury)',
#     'Boston, MA 02113',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d163941735',
#     'name': 'Park',
#     'pluralName': 'Parks',
#     'shortName': 'Park',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4ba50617f964a520f1d138e3-0'}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(50)
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                                                  name  \
# 0                                      North End Park
# 1            The Rose Kennedy Greenway - Mothers Walk
# 2                                Boston Public Market
# 3                            Faneuil Hall Marketplace
# 4                                     Saus Restaurant
# 5                                          Red's Best
# 6                                       Quincy Market
# 7                                      Red Apple Farm
# 8                                George Howell Coffee
# 9                                      Neptune Oyster
# 10                                     Newbury Comics
# 11                                   Big Apple Circus
# 12                                            Pauli's
# 13                       Samuel Adams Boston Tap Room
# 14                              Boston Chowda Company
# 15                              Improv Asylum Theatre
# 16                    Bricco Salumeria and Pasta Shop
# 17                                                 Zo
# 18                           Boston Massacre Monument
# 19                                Union Square Donuts
# 20                                       Mother Juice
# 21                                       Thinking Cup
# 22                                           Cocobeet
# 23                                 Union Oyster House
# 24                                     Levend Bagelry
# 25                                    Ernesto's Pizza
# 26                                Tatte Bakery & Cafe
# 27                                    Old State House
# 28            Wachusett Boston Brew Yard at City Hall
# 29                                               Mare
# 30                                     North End Yoga
# 31                                     Shake the Tree
# 32  Boston National Historical Park Visitor Center...
# 33                                             UNIQLO
# 34                                  Bricco Panetteria
# 35                                             Bricco
# 36                                    Boston Chipyard
# 37                                Maria's Pastry Shop
# 38                                            SEPHORA
# 39                                     Inna's Kitchen
# 40                                Bell In Hand Tavern
# 41                             Al's State Street Cafe
# 42                                 Modern Pastry Shop
# 43                 The New England Holocaust Memorial
# 44                                                 Zo
# 45                         The Oceanaire Seafood Room
# 46                             The Ski Monster Boston
# 47                                      La Dolce Vita
# 48                                               Aria
# 49                      Bon Me - Boston Public Market
#
#                        categories                       address  \
# 0                            Park                     Cross St.
# 1                            Park                           NaN
# 2                          Market                100 Hanover St
# 3                   Historic Site                 1 S Market St
# 4              Belgian Restaurant                   33 Union St
# 5              Seafood Restaurant                100 Hanover St
# 6                   Historic Site             1 Faneuil Hall Sq
# 7                          Bakery                100 Hanover St
# 8                     Coffee Shop                100 Hanover St
# 9              Seafood Restaurant                   63 Salem St
# 10                    Record Shop             1 Faneuil Hall Sq
# 11                         Circus               1 City Hall Ave
# 12                 Sandwich Place                   65 Salem St
# 13                       Beer Bar                   60 State St
# 14             Seafood Restaurant      1 Faneuil Hall Market Pl
# 15                    Comedy Club                216 Hanover St
# 16                  Deli / Bodega                  11 Board Aly
# 17               Greek Restaurant                   92 State St
# 18            Monument / Landmark                     State St.
# 19                     Donut Shop                           NaN
# 20  Vegetarian / Vegan Restaurant                100 Hanover St
# 21                    Coffee Shop                236 Hanover St
# 22                      Juice Bar             100 City Hall Plz
# 23             Seafood Restaurant                   41 Union St
# 24                     Bagel Shop          Boston Public Market
# 25                    Pizza Place                   69 Salem St
# 26                         Bakery                   1 Boston Pl
# 27                  Historic Site             206 Washington St
# 28                    Beer Garden                           NaN
# 29             Italian Restaurant                 3 Mechanic St
# 30                    Yoga Studio                332 Hanover St
# 31                       Boutique                   67 Salem St
# 32     Tourist Information Center              0 Merchant's Row
# 33                 Clothing Store             245 Quincy Market
# 34                         Bakery                241 Hanover St
# 35             Italian Restaurant                241 Hanover St
# 36                         Bakery  257 Faneuil Hall Marketplace
# 37                         Bakery                   46 Cross St
# 38                 Cosmetics Shop                    7 North St
# 39       Mediterranean Restaurant             100 Hanover Stree
# 40                            Pub                   45 Union St
# 41                 Sandwich Place                  112 State St
# 42                         Bakery                263 Hanover St
# 43                  Historic Site               98 Union Street
# 44               Greek Restaurant                  3 Center Plz
# 45             Seafood Restaurant                   40 Court St
# 46                     Ski Chalet                   60 Canal St
# 47             Italian Restaurant                221 Hanover St
# 48             Italian Restaurant               243 Hanover St.
# 49                     Food Truck                100 Hanover St
#
#                                         crossStreet        lat        lng  \
# 0                              btwn North & Sudbury  42.362488 -71.056477
# 1                                               NaN  42.362640 -71.056407
# 2                        btwn Sudbury & Congress St  42.361950 -71.057466
# 3                         at Congress St & North St  42.359978 -71.056410
# 4                                        Marsh Lane  42.361076 -71.057054
# 5                                               NaN  42.361960 -71.057587
# 6                            btwn Clinton & Chatham  42.360106 -71.054881
# 7                                               NaN  42.361827 -71.057536
# 8                                               NaN  42.361832 -71.057445
# 9                                      at Morton St  42.363237 -71.056139
# 10  Faneuil Hall Marketplace, North Market Building  42.360643 -71.054413
# 11                                              NaN  42.360208 -71.059269
# 12                           btwn Morton & Stillman  42.363292 -71.056068
# 13                              South Market Street  42.359582 -71.056657
# 14                                    Quincy Market  42.360164 -71.054969
# 15                           btwn Cross & Parmenter  42.362931 -71.055404
# 16                                              NaN  42.363071 -71.055041
# 17                        Entrance on Merchants Row  42.359196 -71.055467
# 18                                  at Congress St.  42.358955 -71.056971
# 19                                              NaN  42.361925 -71.057280
# 20                                              NaN  42.361862 -71.057340
# 21                                              NaN  42.363221 -71.055124
# 22                                              NaN  42.359757 -71.059085
# 23                                    at Hanover St  42.361371 -71.057152
# 24                                              NaN  42.361873 -71.057473
# 25                           btwn Morton & Stillman  42.363370 -71.055998
# 26                                     State Street  42.358451 -71.057981
# 27                                      at State St  42.358865 -71.057462
# 28                                              NaN  42.359788 -71.057296
# 29                                              NaN  42.362857 -71.054979
# 30                           btwn Cross & Parmenter  42.363554 -71.054832
# 31                                              NaN  42.363333 -71.056014
# 32                                              NaN  42.360017 -71.056205
# 33                                              NaN  42.360090 -71.055143
# 34                          Richmond St & Board Aly  42.363056 -71.054894
# 35                            btwn Cross & Richmond  42.363225 -71.055069
# 36                                              NaN  42.360378 -71.054731
# 37                            btwn Endicott & Salem  42.363074 -71.056731
# 38                                              NaN  42.360341 -71.056080
# 39                                              NaN  42.361836 -71.057411
# 40                                    at Hanover St  42.361542 -71.057207
# 41                btwn Chatham Row & Merchant's Row  42.359071 -71.054804
# 42                            btwn Cross & Richmond  42.363391 -71.054859
# 43                             btwn Hanover & North  42.361059 -71.057179
# 44                                              NaN  42.359303 -71.060352
# 45                                    at Tremont St  42.359071 -71.059173
# 46                                   at Causeway St  42.363679 -71.059239
# 47                           btwn Cross & Parmenter  42.362877 -71.055379
# 48                                              NaN  42.363286 -71.055002
# 49                                              NaN  42.362009 -71.056889
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 42.36248823184806...       157      02113
# 1   [{'label': 'display', 'lat': 42.36263981588581...       175        NaN
# 2   [{'label': 'display', 'lat': 42.36194982978392...        94      02108
# 3   [{'label': 'display', 'lat': 42.35997750557642...       141      02109
# 4   [{'label': 'display', 'lat': 42.36107632380333...         8      02108
# 5   [{'label': 'display', 'lat': 42.36196033446922...        99      02108
# 6                                                 NaN       214      02109
# 7   [{'label': 'display', 'lat': 42.36182685816394...        84      02108
# 8   [{'label': 'display', 'lat': 42.361831810881, ...        82      02108
# 9   [{'label': 'display', 'lat': 42.36323650143622...       245      02113
# 10  [{'label': 'display', 'lat': 42.36064256002904...       226      02109
# 11  [{'label': 'display', 'lat': 42.36020769008986...       207      02108
# 12  [{'label': 'display', 'lat': 42.3632920767292,...       253      02113
# 13  [{'label': 'display', 'lat': 42.35958247674226...       177      02109
# 14  [{'label': 'display', 'lat': 42.36016370686791...       205      02109
# 15  [{'label': 'display', 'lat': 42.36293119004747...       242      02113
# 16  [{'label': 'display', 'lat': 42.36307097234039...       272      02113
# 17  [{'label': 'display', 'lat': 42.35919645427936...       254      02109
# 18  [{'label': 'display', 'lat': 42.35895538628799...       243      02109
# 19  [{'label': 'display', 'lat': 42.361925361552, ...        88        NaN
# 20  [{'label': 'display', 'lat': 42.361862, 'lng':...        82      02108
# 21  [{'label': 'display', 'lat': 42.36322114260519...       281      02113
# 22  [{'label': 'display', 'lat': 42.35975658523581...       225      02108
# 23  [{'label': 'display', 'lat': 42.36137078671901...        25      02108
# 24  [{'label': 'display', 'lat': 42.36187346396489...        87      02108
# 25  [{'label': 'display', 'lat': 42.36337010778569...       263      02113
# 26  [{'label': 'display', 'lat': 42.35845066983387...       308      02108
# 27  [{'label': 'display', 'lat': 42.35886491485705...       255      02109
# 28  [{'label': 'display', 'lat': 42.35978814848613...       152      02108
# 29  [{'label': 'display', 'lat': 42.36285729321035...       257      02113
# 30  [{'label': 'display', 'lat': 42.36355430228779...       325      02113
# 31  [{'label': 'display', 'lat': 42.36333344037822...       258      02113
# 32  [{'label': 'display', 'lat': 42.36001683165030...       144      02109
# 33  [{'label': 'display', 'lat': 42.36008960713943...       198      02109
# 34  [{'label': 'display', 'lat': 42.363056, 'lng':...       278      02113
# 35  [{'label': 'display', 'lat': 42.36322453581476...       284      02113
# 36  [{'label': 'display', 'lat': 42.36037811307418...       211      02109
# 37  [{'label': 'display', 'lat': 42.36307437910619...       216      02113
# 38  [{'label': 'display', 'lat': 42.36034083293764...       121      02109
# 39  [{'label': 'display', 'lat': 42.36183614740884...        81        NaN
# 40  [{'label': 'display', 'lat': 42.36154215910454...        45      02108
# 41  [{'label': 'display', 'lat': 42.35907122186619...       297      02109
# 42  [{'label': 'display', 'lat': 42.36339129541846...       309      02113
# 43  [{'label': 'display', 'lat': 42.36105864798984...        12      02109
# 44  [{'label': 'display', 'lat': 42.35930332664829...       338      02108
# 45  [{'label': 'display', 'lat': 42.3590705, 'lng'...       287      02108
# 46  [{'label': 'display', 'lat': 42.36367897332996...       333      02114
# 47  [{'label': 'display', 'lat': 42.36287675877697...       238      02113
# 48  [{'label': 'display', 'lat': 42.36328588493244...       293      02113
# 49  [{'label': 'display', 'lat': 42.36200856035146...        97      02108
#
#     cc    city state        country  \
# 0   US  Boston    MA  United States
# 1   US  Boston    MA  United States
# 2   US  Boston    MA  United States
# 3   US  Boston    MA  United States
# 4   US  Boston    MA  United States
# 5   US  Boston    MA  United States
# 6   US  Boston    MA  United States
# 7   US  Boston    MA  United States
# 8   US  Boston    MA  United States
# 9   US  Boston    MA  United States
# 10  US  Boston    MA  United States
# 11  US  Boston    MA  United States
# 12  US  Boston    MA  United States
# 13  US  Boston    MA  United States
# 14  US  Boston    MA  United States
# 15  US  Boston    MA  United States
# 16  US  Boston    MA  United States
# 17  US  Boston    MA  United States
# 18  US  Boston    MA  United States
# 19  US  Boston    MA  United States
# 20  US  Boston    MA  United States
# 21  US  Boston    MA  United States
# 22  US  Boston    MA  United States
# 23  US  Boston    MA  United States
# 24  US  Boston    MA  United States
# 25  US  Boston    MA  United States
# 26  US  Boston    MA  United States
# 27  US  Boston    MA  United States
# 28  US  Boston    MA  United States
# 29  US  Boston    MA  United States
# 30  US  Boston    MA  United States
# 31  US  Boston    MA  United States
# 32  US  Boston    MA  United States
# 33  US  Boston    MA  United States
# 34  US  Boston    MA  United States
# 35  US  Boston    MA  United States
# 36  US  Boston    MA  United States
# 37  US  Boston    MA  United States
# 38  US  Boston    MA  United States
# 39  US  Boston    MA  United States
# 40  US  Boston    MA  United States
# 41  US  Boston    MA  United States
# 42  US  Boston    MA  United States
# 43  US  Boston    MA  United States
# 44  US  Boston    MA  United States
# 45  US  Boston    MA  United States
# 46  US  Boston    MA  United States
# 47  US  Boston    MA  United States
# 48  US  Boston    MA  United States
# 49  US  Boston    MA  United States
#
#                                      formattedAddress     neighborhood  \
# 0   [Cross St. (btwn North & Sudbury), Boston, MA ...              NaN
# 1                         [Boston, MA, United States]              NaN
# 2   [100 Hanover St (btwn Sudbury & Congress St), ...              NaN
# 3   [1 S Market St (at Congress St & North St), Bo...  Downtown Boston
# 4   [33 Union St (Marsh Lane), Boston, MA 02108, U...              NaN
# 5   [100 Hanover St, Boston, MA 02108, United States]              NaN
# 6   [1 Faneuil Hall Sq (btwn Clinton & Chatham), B...              NaN
# 7   [100 Hanover St, Boston, MA 02108, United States]  Downtown Boston
# 8   [100 Hanover St, Boston, MA 02108, United States]              NaN
# 9   [63 Salem St (at Morton St), Boston, MA 02113,...              NaN
# 10  [1 Faneuil Hall Sq (Faneuil Hall Marketplace, ...              NaN
# 11  [1 City Hall Ave, Boston, MA 02108, United Sta...              NaN
# 12  [65 Salem St (btwn Morton & Stillman), Boston,...              NaN
# 13  [60 State St (South Market Street), Boston, MA...              NaN
# 14  [1 Faneuil Hall Market Pl (Quincy Market), Bos...              NaN
# 15  [216 Hanover St (btwn Cross & Parmenter), Bost...              NaN
# 16    [11 Board Aly, Boston, MA 02113, United States]              NaN
# 17  [92 State St (Entrance on Merchants Row), Bost...              NaN
# 18  [State St. (at Congress St.), Boston, MA 02109...              NaN
# 19                        [Boston, MA, United States]              NaN
# 20  [100 Hanover St, Boston, MA 02108, United States]              NaN
# 21  [236 Hanover St, Boston, MA 02113, United States]              NaN
# 22  [100 City Hall Plz, Boston, MA 02108, United S...              NaN
# 23  [41 Union St (at Hanover St), Boston, MA 02108...              NaN
# 24  [Boston Public Market, Boston, MA 02108, Unite...              NaN
# 25  [69 Salem St (btwn Morton & Stillman), Boston,...              NaN
# 26  [1 Boston Pl (State Street), Boston, MA 02108,...              NaN
# 27  [206 Washington St (at State St), Boston, MA 0...              NaN
# 28                  [Boston, MA 02108, United States]              NaN
# 29   [3 Mechanic St, Boston, MA 02113, United States]              NaN
# 30  [332 Hanover St (btwn Cross & Parmenter), Bost...              NaN
# 31     [67 Salem St, Boston, MA 02113, United States]              NaN
# 32  [0 Merchant's Row, Boston, MA 02109, United St...              NaN
# 33  [245 Quincy Market, Boston, MA 02109, United S...              NaN
# 34  [241 Hanover St (Richmond St & Board Aly), Bos...              NaN
# 35  [241 Hanover St (btwn Cross & Richmond), Bosto...              NaN
# 36  [257 Faneuil Hall Marketplace, Boston, MA 0210...              NaN
# 37  [46 Cross St (btwn Endicott & Salem), Boston, ...              NaN
# 38      [7 North St, Boston, MA 02109, United States]              NaN
# 39     [100 Hanover Stree, Boston, MA, United States]              NaN
# 40  [45 Union St (at Hanover St), Boston, MA 02108...              NaN
# 41  [112 State St (btwn Chatham Row & Merchant's R...              NaN
# 42  [263 Hanover St (btwn Cross & Richmond), Bosto...              NaN
# 43  [98 Union Street (btwn Hanover & North), Bosto...  Downtown Boston
# 44    [3 Center Plz, Boston, MA 02108, United States]              NaN
# 45  [40 Court St (at Tremont St), Boston, MA 02108...              NaN
# 46  [60 Canal St (at Causeway St), Boston, MA 0211...              NaN
# 47  [221 Hanover St (btwn Cross & Parmenter), Bost...              NaN
# 48  [243 Hanover St., Boston, MA 02113, United Sta...              NaN
# 49  [100 Hanover St, Boston, MA 02108, United States]              NaN
#
#                           id
# 0   4ba50617f964a520f1d138e3
# 1   51743d0ce4b0d8599417b780
# 2   55b95c01498e77bdd5be7a96
# 3   4b3d563ff964a520a49225e3
# 4   4bf18c843506ef3bea63bd22
# 5   565f3316498e9ca911292760
# 6   4a1b3cd9f964a520db7a1fe3
# 7   563f7d83cd108b8d94e3e859
# 8   55c7541b498e1c44d8c3e506
# 9   4ac53112f964a520dbb020e3
# 10  4afc4d3bf964a520512122e3
# 11  514deadde4b04b410e36516b
# 12  4dea5487d164ef597ce79171
# 13  5e2a56278cbc2c0008f1cd8e
# 14  4bc510d422c676b0c89096d3
# 15  40b28c80f964a520d5f71ee3
# 16  53a74381498e34ef9a6217ea
# 17  4f049c5d00399761c77a111b
# 18  4db0389a6e81a2637ed498b3
# 19  55c78867498ebead01857033
# 20  57d1d861498e8267bbe82bc4
# 21  50c61b1ae4b0bd0f65b00b19
# 22  52f5138a498e068de20c312d
# 23  45a152ecf964a520e0401fe3
# 24  5781547b38faa3a2e8579c92
# 25  4accca58f964a52087c920e3
# 26  5c95073698fbfc002c2847c1
# 27  4ae721b1f964a520b3a821e3
# 28  59cd6e3ca2a6ce39472cb01c
# 29  5807a41638fad61b2ebda69c
# 30  4c23f473a852c9282364e26c
# 31  4b2a6b72f964a520d4a824e3
# 32  4f26a5f1e4b01dc94dc3db52
# 33  53ce8f4a498e4047bd712076
# 34  4f1acf60e4b0850c83800d9c
# 35  4c52e8669d642d7fc892cddf
# 36  4b12df8af964a520db8f23e3
# 37  4a94cbcff964a520782220e3
# 38  58a68b3292ca4c07d59e9093
# 39  55ba9599498ee671eb9076da
# 40  40b28c80f964a52090f71ee3
# 41  4abe4eaaf964a520968c20e3
# 42  4a3d99aef964a52083a21fe3
# 43  4b5397e3f964a520d8a327e3
# 44  4b4f6a57f964a520930527e3
# 45  4a457a60f964a5203fa81fe3
# 46  53dff5aa498e8db166762d66
# 47  4afe20f2f964a520292e22e3
# 48  51203506e4b06730aceca3c5
# 49  56a1135b498e8268ad5b5e81

# %% [markdown]
# ## Redundant columns are eliminated

# %%
df=dataframe_filtered[['categories','postalCode','lat','lng','id']]
df=df.dropna(subset=["postalCode"], axis=0)
df
# Out:
#                     categories postalCode        lat        lng  \
# 0                         Park      02113  42.362488 -71.056477
# 2                       Market      02108  42.361950 -71.057466
# 3                Historic Site      02109  42.359978 -71.056410
# 4           Belgian Restaurant      02108  42.361076 -71.057054
# 5           Seafood Restaurant      02108  42.361960 -71.057587
# ..                         ...        ...        ...        ...
# 95              Lingerie Store      02109  42.359803 -71.054357
# 96                 Pizza Place      02113  42.365394 -71.056883
# 97          Italian Restaurant      02113  42.364169 -71.055559
# 98  Tourist Information Center      02110  42.360232 -71.052371
# 99                        Café      02109  42.358467 -71.057648
#
#                           id
# 0   4ba50617f964a520f1d138e3
# 2   55b95c01498e77bdd5be7a96
# 3   4b3d563ff964a520a49225e3
# 4   4bf18c843506ef3bea63bd22
# 5   565f3316498e9ca911292760
# ..                       ...
# 95  4b54e636f964a52019d227e3
# 96  4ae4b71af964a520629d21e3
# 97  4aeb408ef964a52023c021e3
# 98  4e340b82483b5fa58752a25a
# 99  5bd8f4b4f709c1002cc147cd
#
# [96 rows x 5 columns]

# %% [markdown]
# ## Finding out number of Italian Restaurants

# %%
d=dataframe_filtered.loc[dataframe_filtered['categories'] == 'Italian Restaurant']

# %%
df_new = d.groupby(['postalCode', 'categories']).count()
df_new
# Out:
#                                name  address  crossStreet  lat  lng  \
# postalCode categories
# 02108      Italian Restaurant     1        1            0    1    1
# 02109      Italian Restaurant     1        1            1    1    1
# 02113      Italian Restaurant    14       14            9   14   14
#
#                                labeledLatLngs  distance  cc  city  state  \
# postalCode categories
# 02108      Italian Restaurant               1         1   1     1      1
# 02109      Italian Restaurant               1         1   1     1      1
# 02113      Italian Restaurant              14        14  14    14     14
#
#                                country  formattedAddress  neighborhood  id
# postalCode categories
# 02108      Italian Restaurant        1                 1             0   1
# 02109      Italian Restaurant        1                 1             0   1
# 02113      Italian Restaurant       14                14             0  14

# %%
df.postalCode.unique()
# Out:
# array(['02113', '02108', '02109', '02114', '02201-1001', '02110'],
#       dtype=object)

# %% [markdown]
# ## New dataframe with postal codes and number of Italian Restaurants

# %%
data = {'postalCode':  ['02113', '02108','02109','02114','02110','02111','02201-1001'],
        'number of Italian Restaurants': ['15', '1','1','0','0','0','0']
        }

# %%
df2 = pd.DataFrame (data, columns = ['postalCode','number of Italian Restaurants'])

df2
# Out:
#    postalCode number of Italian Restaurants
# 0       02113                            15
# 1       02108                             1
# 2       02109                             1
# 3       02114                             0
# 4       02110                             0
# 5       02111                             0
# 6  02201-1001                             0

# %%
combined_data = df.join(df2.set_index('postalCode'), on='postalCode', how='inner')
combined_data
# Out:
#                     categories  postalCode        lat        lng  \
# 0                         Park       02113  42.362488 -71.056477
# 9           Seafood Restaurant       02113  42.363237 -71.056139
# 12              Sandwich Place       02113  42.363292 -71.056068
# 15                 Comedy Club       02113  42.362931 -71.055404
# 16               Deli / Bodega       02113  42.363071 -71.055041
# ..                         ...         ...        ...        ...
# 46                  Ski Chalet       02114  42.363679 -71.059239
# 51                 Coffee Shop       02114  42.363144 -71.059830
# 87                       Plaza  02201-1001  42.359652 -71.059477
# 94                        Park       02110  42.361027 -71.051451
# 98  Tourist Information Center       02110  42.360232 -71.052371
#
#                           id number of Italian Restaurants
# 0   4ba50617f964a520f1d138e3                            15
# 9   4ac53112f964a520dbb020e3                            15
# 12  4dea5487d164ef597ce79171                            15
# 15  40b28c80f964a520d5f71ee3                            15
# 16  53a74381498e34ef9a6217ea                            15
# ..                       ...                           ...
# 46  53dff5aa498e8db166762d66                             0
# 51  51a49c41498e034cea66e562                             0
# 87  4a74b8c9f964a5205edf1fe3                             0
# 94  4ae3580af964a520c59321e3                             0
# 98  4e340b82483b5fa58752a25a                             0
#
# [96 rows x 6 columns]

# %%
combined_data=combined_data.reset_index()

combined_data
# Out:
#     index                  categories  postalCode        lat        lng  \
# 0       0                        Park       02113  42.362488 -71.056477
# 1       9          Seafood Restaurant       02113  42.363237 -71.056139
# 2      12              Sandwich Place       02113  42.363292 -71.056068
# 3      15                 Comedy Club       02113  42.362931 -71.055404
# 4      16               Deli / Bodega       02113  42.363071 -71.055041
# ..    ...                         ...         ...        ...        ...
# 91     46                  Ski Chalet       02114  42.363679 -71.059239
# 92     51                 Coffee Shop       02114  42.363144 -71.059830
# 93     87                       Plaza  02201-1001  42.359652 -71.059477
# 94     94                        Park       02110  42.361027 -71.051451
# 95     98  Tourist Information Center       02110  42.360232 -71.052371
#
#                           id number of Italian Restaurants
# 0   4ba50617f964a520f1d138e3                            15
# 1   4ac53112f964a520dbb020e3                            15
# 2   4dea5487d164ef597ce79171                            15
# 3   40b28c80f964a520d5f71ee3                            15
# 4   53a74381498e34ef9a6217ea                            15
# ..                       ...                           ...
# 91  53dff5aa498e8db166762d66                             0
# 92  51a49c41498e034cea66e562                             0
# 93  4a74b8c9f964a5205edf1fe3                             0
# 94  4ae3580af964a520c59321e3                             0
# 95  4e340b82483b5fa58752a25a                             0
#
# [96 rows x 7 columns]

# %% [markdown]
# ## We'll keep this dataframe for now, later other columns will be added to this dataframe.

# %%
combined_data.drop(['index'], axis = 'columns', inplace = True)
combined_data.head(100)
# Out:
#                     categories  postalCode        lat        lng  \
# 0                         Park       02113  42.362488 -71.056477
# 1           Seafood Restaurant       02113  42.363237 -71.056139
# 2               Sandwich Place       02113  42.363292 -71.056068
# 3                  Comedy Club       02113  42.362931 -71.055404
# 4                Deli / Bodega       02113  42.363071 -71.055041
# ..                         ...         ...        ...        ...
# 91                  Ski Chalet       02114  42.363679 -71.059239
# 92                 Coffee Shop       02114  42.363144 -71.059830
# 93                       Plaza  02201-1001  42.359652 -71.059477
# 94                        Park       02110  42.361027 -71.051451
# 95  Tourist Information Center       02110  42.360232 -71.052371
#
#                           id number of Italian Restaurants
# 0   4ba50617f964a520f1d138e3                            15
# 1   4ac53112f964a520dbb020e3                            15
# 2   4dea5487d164ef597ce79171                            15
# 3   40b28c80f964a520d5f71ee3                            15
# 4   53a74381498e34ef9a6217ea                            15
# ..                       ...                           ...
# 91  53dff5aa498e8db166762d66                             0
# 92  51a49c41498e034cea66e562                             0
# 93  4a74b8c9f964a5205edf1fe3                             0
# 94  4ae3580af964a520c59321e3                             0
# 95  4e340b82483b5fa58752a25a                             0
#
# [96 rows x 6 columns]

# %% [markdown]
# ### We try to find out which venues are trending in order to have a guess on the popularity of the area

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fdfc9938c47f042d7f8b28a'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# ### Since there are no trending areas, we should find another way to evaluate the popularness of the area
# ### As a sign of popularity I preffered to use total number of tips, the more tips are written the more area is used
# ### The IDs of of Italian Restaurants within postal code areas 02113,02108,02109 are used to find the ratings of restaurants and the total number of tips
#
# ### Areas other then 02113,02108,02109 have no Italian restaurants therefore they are not used in the queries below
#
# ### Finding the ids of Italian Restaurants in the Postal Code area 02108:

# %%
df = combined_data[(combined_data['categories'] == 'Italian Restaurant') & (combined_data['postalCode'] == '02108')]
df
# Out:
#             categories postalCode        lat       lng  \
# 54  Italian Restaurant      02108  42.358025 -71.05905
#
#                           id number of Italian Restaurants
# 54  58541f39ce593d53043e55d0                             1

# %% [markdown]
# ### There is only one restaurant its rating and number of tips are retrieved and stored in variables rating&count

# %%
venue_id = '58541f39ce593d53043e55d0'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.3

# %%
count=result['response']['venue']['tips']['count']
count
# Out:
# 5

# %% [markdown]
# ### Finding the ids of Italian Restaurants in the Postal Code area 02109 and using the ID to retrieve ratings and number of counts:

# %%
df = combined_data[(combined_data['categories'] == 'Italian Restaurant') & (combined_data['postalCode'] == '02109')]
df
# Out:
#             categories postalCode        lat        lng  \
# 76  Italian Restaurant      02109  42.358231 -71.054741
#
#                           id number of Italian Restaurants
# 76  4d1a255481cea35d5867faec                             1

# %%
venue_id = '4d1a255481cea35d5867faec'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating1=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.6

# %%
count1=result['response']['venue']['tips']['count']
count1
# Out:
# 28

# %% [markdown]
# ### Finding the ids of Italian Restaurants in the Postal Code area 02113 and using the ID to retrieve ratings and number of counts:

# %%
df = combined_data[(combined_data['categories'] == 'Italian Restaurant') & (combined_data['postalCode'] == '02113')]
df
# Out:
#             categories postalCode        lat        lng  \
# 7   Italian Restaurant      02113  42.362857 -71.054979
# 11  Italian Restaurant      02113  42.363225 -71.055069
# 14  Italian Restaurant      02113  42.362877 -71.055379
# 15  Italian Restaurant      02113  42.363286 -71.055002
# 18  Italian Restaurant      02113  42.363353 -71.053827
# 19  Italian Restaurant      02113  42.363135 -71.055160
# 21  Italian Restaurant      02113  42.363059 -71.055239
# 22  Italian Restaurant      02113  42.363836 -71.054500
# 23  Italian Restaurant      02113  42.364027 -71.054293
# 25  Italian Restaurant      02113  42.363313 -71.053840
# 26  Italian Restaurant      02113  42.362523 -71.055644
# 29  Italian Restaurant      02113  42.363656 -71.054700
# 31  Italian Restaurant      02113  42.364062 -71.053475
# 34  Italian Restaurant      02113  42.364169 -71.055559
#
#                           id number of Italian Restaurants
# 7   5807a41638fad61b2ebda69c                            15
# 11  4c52e8669d642d7fc892cddf                            15
# 14  4afe20f2f964a520292e22e3                            15
# 15  51203506e4b06730aceca3c5                            15
# 18  4a5150b1f964a520eab01fe3                            15
# 19  534c8689498e86384e21ee16                            15
# 21  4a692cedf964a520b8cb1fe3                            15
# 22  4a3bfa61f964a520f6a01fe3                            15
# 23  4f371a61e4b0beedd1b36f56                            15
# 25  4b70a8f8f964a52024282de3                            15
# 26  4b8d5e62f964a5207cf732e3                            15
# 29  514a10fbe4b07613314b7639                            15
# 31  4a933294f964a5202d1f20e3                            15
# 34  4aeb408ef964a52023c021e3                            15

# %%
venue_id = '5807a41638fad61b2ebda69c'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating2=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.2

# %%
count2=result['response']['venue']['tips']['count']
count2
# Out:
# 1

# %%
venue_id = '4c52e8669d642d7fc892cddf'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating3=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.3

# %%
count3=result['response']['venue']['tips']['count']
count3
# Out:
# 76

# %%
76
venue_id = '4afe20f2f964a520292e22e3'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating4=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %%
count4=result['response']['venue']['tips']['count']
count4
# Out:
# 38

# %%
venue_id = '4a5150b1f964a520eab01fe3'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating5=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.6

# %%
count5=result['response']['venue']['tips']['count']
count5
# Out:
# 31

# %%
venue_id = '534c8689498e86384e21ee16'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating6=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %%
count6=result['response']['venue']['tips']['count']
count6
# Out:
# 24

# %%
venue_id = '51203506e4b06730aceca3c5'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating7=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.2

# %%
count7=result['response']['venue']['tips']['count']
count7
# Out:
# 8

# %%
venue_id = '4a692cedf964a520b8cb1fe3'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating8=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %%
count8=result['response']['venue']['tips']['count']
count8
# Out:
# 32

# %%
venue_id = '4a3bfa61f964a520f6a01fe3'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating9=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.6

# %%
count9=result['response']['venue']['tips']['count']
count9
# Out:
# 99

# %%
venue_id = '4f371a61e4b0beedd1b36f56'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating10=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.8

# %%
count10=result['response']['venue']['tips']['count']
count10
# Out:
# 59

# %%
venue_id = '4b70a8f8f964a52024282de3'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating11=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.3

# %%
count11=result['response']['venue']['tips']['count']
count11
# Out:
# 13

# %%
venue_id = '4b8d5e62f964a5207cf732e3'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating12=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 7.5

# %%
count12=result['response']['venue']['tips']['count']
count12
# Out:
# 12

# %%
venue_id = '514a10fbe4b07613314b7639'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating13=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.1

# %%
count13=result['response']['venue']['tips']['count']
count13
# Out:
# 39

# %%
venue_id = '4a933294f964a5202d1f20e3'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating14=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.7

# %%
count14=result['response']['venue']['tips']['count']
count14
# Out:
# 40

# %%
venue_id = '4aeb408ef964a52023c021e3'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating15=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.0

# %%
count15=result['response']['venue']['tips']['count']
count15
# Out:
# 51

# %%
venue_id = '4ada50baf964a520442121e3'

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
    rating16=result['response']['venue']['rating']
except:
    print('This venue has not been rated yet.')
# Out:
# 8.2

# %%
count16=result['response']['venue']['tips']['count']
count16
# Out:
# 37

# %% [markdown]
# ### All number of counts and ratings are saved into lists for area 02113

# %%
count_list_02113=[]
count_list_02113.append(count2)
count_list_02113.append(count3)
count_list_02113.append(count4)
count_list_02113.append(count5)
count_list_02113.append(count6)
count_list_02113.append(count7)
count_list_02113.append(count8)
count_list_02113.append(count9)
count_list_02113.append(count10)
count_list_02113.append(count11)
count_list_02113.append(count12)
count_list_02113.append(count13)
count_list_02113.append(count14)
count_list_02113.append(count15)
count_list_02113.append(count16)

rating_list_02113=[]
rating_list_02113.append(rating2)
rating_list_02113.append(rating3)
rating_list_02113.append(rating4)
rating_list_02113.append(rating5)
rating_list_02113.append(rating6)
rating_list_02113.append(rating7)
rating_list_02113.append(rating8)
rating_list_02113.append(rating9)
rating_list_02113.append(rating10)
rating_list_02113.append(rating11)
rating_list_02113.append(rating12)
rating_list_02113.append(rating13)
rating_list_02113.append(rating14)
rating_list_02113.append(rating15)
rating_list_02113.append(rating16)

# %%
print(count_list_02113)

print(rating_list_02113)
# Out:
# [1, 76, 38, 31, 24, 8, 32, 99, 59, 13, 12, 39, 40, 51, 37]
# [8.2, 8.3, 7.9, 8.6, 7.9, 8.2, 7.9, 8.6, 8.8, 8.3, 7.5, 8.1, 8.7, 8.0, 8.2]

# %% [markdown]
# ### For area 02113 the rating average is taken and count of tips are summed

# %%
import statistics

mean_rating= statistics.mean(rating_list_02113)

print(mean_rating)
# Out:
# 8.213333333333333

# %%
1+ 76+38+31+24+8+32+99+59+13+12+39+40+51+37
# Out:
# 560

# %% [markdown]
# ## The postal code, Average Ranking and Count of Tips info is stored in a new dataframe

# %%
data = {'postalCode':  ['02113', '02108','02109','02114','02110','02111','02201'],
        'Average Ranking of Italian Restaurant': ['8.2', '8.3','8.6','0','0','0','0'],
         'Count of Tips':['560','5','28','0','0','0','0']
        }

df = pd.DataFrame (data, columns = ['postalCode','Average Ranking of Italian Restaurant','Count of Tips'])
df
# Out:
#   postalCode Average Ranking of Italian Restaurant Count of Tips
# 0      02113                                   8.2           560
# 1      02108                                   8.3             5
# 2      02109                                   8.6            28
# 3      02114                                     0             0
# 4      02110                                     0             0
# 5      02111                                     0             0
# 6      02201                                     0             0

# %%
last_frame = df.join(combined_data.set_index('postalCode'), on='postalCode', how='inner')
last_frame.head(30)
# Out:
#   postalCode Average Ranking of Italian Restaurant Count of Tips  \
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
# 0      02113                                   8.2           560
#
#            categories        lat        lng                        id  \
# 0                Park  42.362488 -71.056477  4ba50617f964a520f1d138e3
# 0  Seafood Restaurant  42.363237 -71.056139  4ac53112f964a520dbb020e3
# 0      Sandwich Place  42.363292 -71.056068  4dea5487d164ef597ce79171
# 0         Comedy Club  42.362931 -71.055404  40b28c80f964a520d5f71ee3
# 0       Deli / Bodega  42.363071 -71.055041  53a74381498e34ef9a6217ea
# 0         Coffee Shop  42.363221 -71.055124  50c61b1ae4b0bd0f65b00b19
# 0         Pizza Place  42.363370 -71.055998  4accca58f964a52087c920e3
# 0  Italian Restaurant  42.362857 -71.054979  5807a41638fad61b2ebda69c
# 0         Yoga Studio  42.363554 -71.054832  4c23f473a852c9282364e26c
# 0            Boutique  42.363333 -71.056014  4b2a6b72f964a520d4a824e3
# 0              Bakery  42.363056 -71.054894  4f1acf60e4b0850c83800d9c
# 0  Italian Restaurant  42.363225 -71.055069  4c52e8669d642d7fc892cddf
# 0              Bakery  42.363074 -71.056731  4a94cbcff964a520782220e3
# 0              Bakery  42.363391 -71.054859  4a3d99aef964a52083a21fe3
# 0  Italian Restaurant  42.362877 -71.055379  4afe20f2f964a520292e22e3
# 0  Italian Restaurant  42.363286 -71.055002  51203506e4b06730aceca3c5
# 0        Neighborhood  42.363697 -71.054672  50afd866e4b004e6d251ea84
# 0        Gourmet Shop  42.364125 -71.055513  40b28c80f964a520d6f71ee3
# 0  Italian Restaurant  42.363353 -71.053827  4a5150b1f964a520eab01fe3
# 0  Italian Restaurant  42.363135 -71.055160  534c8689498e86384e21ee16
# 0         Pizza Place  42.363874 -71.054377  4ac4dfeff964a520549f20e3
# 0  Italian Restaurant  42.363059 -71.055239  4a692cedf964a520b8cb1fe3
# 0  Italian Restaurant  42.363836 -71.054500  4a3bfa61f964a520f6a01fe3
# 0  Italian Restaurant  42.364027 -71.054293  4f371a61e4b0beedd1b36f56
# 0                Café  42.364037 -71.054303  4ae0f451f964a520018421e3
# 0  Italian Restaurant  42.363313 -71.053840  4b70a8f8f964a52024282de3
# 0  Italian Restaurant  42.362523 -71.055644  4b8d5e62f964a5207cf732e3
# 0  Salon / Barbershop  42.364327 -71.055599  4bae214af964a520db873be3
# 0         Fish Market  42.364027 -71.055631  4b95883df964a520dba734e3
# 0  Italian Restaurant  42.363656 -71.054700  514a10fbe4b07613314b7639
#
#   number of Italian Restaurants
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15
# 0                            15

# %%
data_crime
# Out:
#    DISTRICT          STREET        Lat       Long
# 1     02127  MARY BOYLE WAY  42.330813 -71.051368
# 2     02136    READVILLE ST  42.239491 -71.135954
# 3     02130          DAY ST  42.325122 -71.107779
# 4     02122       GIBSON ST  42.297555 -71.059709
# 5     02135       BROOKS ST  42.355120 -71.162678
# ..      ...             ...        ...        ...
# 95    02122     COLUMBIA RD  42.309692 -71.072859
# 96    02122       LESLIE ST  42.295147 -71.058608
# 97    02128       LONDON ST  42.375684 -71.036249
# 98    02119       CEDRIC ST  42.325714 -71.071317
# 99    02124    WALK HILL ST  42.280827 -71.097547
#
# [98 rows x 4 columns]

# %%
data_crime.DISTRICT.unique()
# Out:
# array(['02127', '02136', '02130', '02122', '02135', '02119', '02114',
#        '02132', '02124', '02128', '02116'], dtype=object)

# %%
last_frame.postalCode.unique()
# Out:
# array(['02113', '02108', '02109', '02114', '02110'], dtype=object)

# %% [markdown]
# ## Foursquare dataset and crime dataset have only postal code 02114 in common, therefore we only check for the records of postal code area 02114. There are 13 recordings found.

# %%
data_crime[data_crime['DISTRICT']=='02114']
# Out:
#    DISTRICT         STREET        Lat       Long
# 11    02114        MAIN ST  42.373800 -71.062903
# 16    02114     CHARLES ST  42.359132 -71.070743
# 18    02114  LONGFELLOW PL  42.363565 -71.064493
# 19    02114  WASHINGTON ST  42.356800 -71.058930
# 20    02114       PARK PLZ  42.351627 -71.068664
# 24    02114     TREMONT ST  42.375962 -71.057472
# 25    02114  WASHINGTON ST  42.355919 -71.060005
# 41    02114      N MEAD ST  42.381846 -71.066551
# 43    02114      NASHUA ST  42.367690 -71.065863
# 48    02114    CAUSEWAY ST  42.364331 -71.063193
# 49    02114    CAUSEWAY ST  42.364331 -71.063193
# 60    02114     TREMONT ST  42.355942 -71.062583
# 67    02114     TREMONT ST  42.356375 -71.062135

# %%
data_price.ST_NAME.unique()
# Out:
# array(['02108 ', '02108', '02110', '02128', '02136'], dtype=object)

# %% [markdown]
# ## The average price of postal code 02108 is found from house pricing dataframe

# %%
data_price.loc[data_price['ST_NAME'] == '02108']
# Out:
#     ZIPCODE ST_NAME  AV_TOTAL
# 25   2108.0   02108   2678800
# 26   2108.0   02108    976027
# 27   2108.0   02108    894473

# %%
2678800+976027+894473
# Out:
# 4549300

# %%
4549300/3
# Out:
# 1516433.3333333333

# %% [markdown]
# ## The average price of postal code 02110 is found from house pricing dataframe

# %%
data_price.loc[data_price['ST_NAME'] == '02110']
# Out:
#     ZIPCODE ST_NAME  AV_TOTAL
# 60   2128.0   02110    541200

# %% [markdown]
# ## The missing entries are will be filled with the mean value of the housing price.

# %%
data_price.mean()
# Out:
# ZIPCODE       2116.00
# AV_TOTAL    981968.24
# dtype: float64

# %%
last_frame
# Out:
#    postalCode Average Ranking of Italian Restaurant Count of Tips  \
# 0       02113                                   8.2           560
# 0       02113                                   8.2           560
# 0       02113                                   8.2           560
# 0       02113                                   8.2           560
# 0       02113                                   8.2           560
# ..        ...                                   ...           ...
# 2       02109                                   8.6            28
# 3       02114                                     0             0
# 3       02114                                     0             0
# 4       02110                                     0             0
# 4       02110                                     0             0
#
#                     categories        lat        lng  \
# 0                         Park  42.362488 -71.056477
# 0           Seafood Restaurant  42.363237 -71.056139
# 0               Sandwich Place  42.363292 -71.056068
# 0                  Comedy Club  42.362931 -71.055404
# 0                Deli / Bodega  42.363071 -71.055041
# ..                         ...        ...        ...
# 2                         Café  42.358467 -71.057648
# 3                   Ski Chalet  42.363679 -71.059239
# 3                  Coffee Shop  42.363144 -71.059830
# 4                         Park  42.361027 -71.051451
# 4   Tourist Information Center  42.360232 -71.052371
#
#                           id number of Italian Restaurants
# 0   4ba50617f964a520f1d138e3                            15
# 0   4ac53112f964a520dbb020e3                            15
# 0   4dea5487d164ef597ce79171                            15
# 0   40b28c80f964a520d5f71ee3                            15
# 0   53a74381498e34ef9a6217ea                            15
# ..                       ...                           ...
# 2   5bd8f4b4f709c1002cc147cd                             1
# 3   53dff5aa498e8db166762d66                             0
# 3   51a49c41498e034cea66e562                             0
# 4   4ae3580af964a520c59321e3                             0
# 4   4e340b82483b5fa58752a25a                             0
#
# [95 rows x 8 columns]

# %% [markdown]
# ## Checking for correlation between number of italian restaurants and count of tips

# %%
last_frame.plot.scatter(x = 'Count of Tips', y = 'number of Italian Restaurants')

# %% [markdown]
# ## df is designed for k-means modelling

# %% [markdown]
# ## 13 crimes in 02114, 0 in others

# %%
data = {'postalCode':  ['02113', '02108','02109','02114','02110','02111','02201-1001'],
        'Average Ranking of Italian Restaurant': [8.2, 8.3,8.6, 0, 0, 0, 0],
         'Count of Tips':[560, 5, 28, 0, 0, 0, 0],
        'Average of House Prices':[981968.24,1516433.33,981968.24,981968.24,541200,981968.24,981968.24],
        'Number of Crime Incidents':[0,0,0,13,0,0,0],
        'Number of Italian Restaurants': [15,1,1,0,0,0,0]
       
        }

df = pd.DataFrame (data, columns = ['postalCode','Average Ranking of Italian Restaurant','Count of Tips','Average of House Prices','Number of Crime Incidents','Number of Italian Restaurants'])
df
# Out:
#    postalCode  Average Ranking of Italian Restaurant  Count of Tips  \
# 0       02113                                    8.2            560
# 1       02108                                    8.3              5
# 2       02109                                    8.6             28
# 3       02114                                    0.0              0
# 4       02110                                    0.0              0
# 5       02111                                    0.0              0
# 6  02201-1001                                    0.0              0
#
#    Average of House Prices  Number of Crime Incidents  \
# 0                981968.24                          0
# 1               1516433.33                          0
# 2                981968.24                          0
# 3                981968.24                         13
# 4                541200.00                          0
# 5                981968.24                          0
# 6                981968.24                          0
#
#    Number of Italian Restaurants
# 0                             15
# 1                              1
# 2                              1
# 3                              0
# 4                              0
# 5                              0
# 6                              0

# %% [markdown]
# ## Checking for correlation between features

# %%
df.plot.scatter(x = 'Count of Tips', y = 'Average of House Prices')

# %%
df.plot.scatter(x = 'Number of Italian Restaurants', y = 'Number of Crime Incidents')

# %%
df.plot.scatter(x = 'Average of House Prices', y = 'Number of Crime Incidents')

# %% [markdown]
# ## K-MEANS

# %%
from sklearn.cluster import KMeans 
import matplotlib.pyplot as plt  
from matplotlib import style

# %%
X = df.values[:,1:]

# %%
from sklearn.preprocessing import StandardScaler
X = np.nan_to_num(X)
cluster_dataset = StandardScaler().fit_transform(X)
cluster_dataset
# Out:
# array([[ 1.11404482,  2.44657884, -0.0511865 , -0.40824829,  2.44068086],
#        [ 1.1381882 , -0.41033694,  1.99265777, -0.40824829, -0.2773501 ],
#        [ 1.21061836, -0.29194223, -0.0511865 , -0.40824829, -0.2773501 ],
#        [-0.86571285, -0.43607492, -0.0511865 ,  2.44948974, -0.47149517],
#        [-0.86571285, -0.43607492, -1.73672529, -0.40824829, -0.47149517],
#        [-0.86571285, -0.43607492, -0.0511865 , -0.40824829, -0.47149517],
#        [-0.86571285, -0.43607492, -0.0511865 , -0.40824829, -0.47149517]])

# %% [markdown]
# ## Looking for optimal value of k, since elbow point is at k=3, we select k=3

# %%
cost =[] 
for i in range(1, 6): 
    KM = KMeans(n_clusters = i, max_iter = 500) 
    KM.fit(X) 
      
    # calculates squared error 
    # for the clustered points 
    cost.append(KM.inertia_)      
  
# plot the cost against K values 
plt.plot(range(1, 6), cost, color ='g', linewidth ='3') 
plt.xlabel("Value of K") 
plt.ylabel("Sqaured Error (Cost)") 
plt.show() # clear the plot 
  
# the point of the elbow is the  
# most optimal value for choosing k

# %%
num_clusters = 3

k_means = KMeans(init="k-means++", n_clusters=num_clusters, n_init=12)
k_means.fit(cluster_dataset)
labels = k_means.labels_

print(labels)
# Out:
# [2 1 1 0 0 0 0]

# %%
df["Labels"] = labels

# %% [markdown]
# ## What these labels indicate?

# %%
df.groupby('Labels').mean()
# Out:
#         Average Ranking of Italian Restaurant  Count of Tips  \
# Labels
# 0                                        0.00            0.0
# 1                                        8.45           16.5
# 2                                        8.20          560.0
#
#         Average of House Prices  Number of Crime Incidents  \
# Labels
# 0                    871776.180                       3.25
# 1                   1249200.785                       0.00
# 2                    981968.240                       0.00
#
#         Number of Italian Restaurants
# Labels
# 0                                 0.0
# 1                                 1.0
# 2                                15.0

# %%
df
# Out:
#    postalCode  Average Ranking of Italian Restaurant  Count of Tips  \
# 0       02113                                    8.2            560
# 1       02108                                    8.3              5
# 2       02109                                    8.6             28
# 3       02114                                    0.0              0
# 4       02110                                    0.0              0
# 5       02111                                    0.0              0
# 6  02201-1001                                    0.0              0
#
#    Average of House Prices  Number of Crime Incidents  \
# 0                981968.24                          0
# 1               1516433.33                          0
# 2                981968.24                          0
# 3                981968.24                         13
# 4                541200.00                          0
# 5                981968.24                          0
# 6                981968.24                          0
#
#    Number of Italian Restaurants  Labels
# 0                             15       2
# 1                              1       1
# 2                              1       1
# 3                              0       0
# 4                              0       0
# 5                              0       0
# 6                              0       0

# %%
map_frame=pd.merge(df, last_frame, on="postalCode")
map_frame
# Out:
#    postalCode  Average Ranking of Italian Restaurant_x  Count of Tips_x  \
# 0       02113                                      8.2              560
# 1       02113                                      8.2              560
# 2       02113                                      8.2              560
# 3       02113                                      8.2              560
# 4       02113                                      8.2              560
# ..        ...                                      ...              ...
# 90      02109                                      8.6               28
# 91      02114                                      0.0                0
# 92      02114                                      0.0                0
# 93      02110                                      0.0                0
# 94      02110                                      0.0                0
#
#     Average of House Prices  Number of Crime Incidents  \
# 0                 981968.24                          0
# 1                 981968.24                          0
# 2                 981968.24                          0
# 3                 981968.24                          0
# 4                 981968.24                          0
# ..                      ...                        ...
# 90                981968.24                          0
# 91                981968.24                         13
# 92                981968.24                         13
# 93                541200.00                          0
# 94                541200.00                          0
#
#     Number of Italian Restaurants  Labels  \
# 0                              15       2
# 1                              15       2
# 2                              15       2
# 3                              15       2
# 4                              15       2
# ..                            ...     ...
# 90                              1       1
# 91                              0       0
# 92                              0       0
# 93                              0       0
# 94                              0       0
#
#    Average Ranking of Italian Restaurant_y Count of Tips_y  \
# 0                                      8.2             560
# 1                                      8.2             560
# 2                                      8.2             560
# 3                                      8.2             560
# 4                                      8.2             560
# ..                                     ...             ...
# 90                                     8.6              28
# 91                                       0               0
# 92                                       0               0
# 93                                       0               0
# 94                                       0               0
#
#                     categories        lat        lng  \
# 0                         Park  42.362488 -71.056477
# 1           Seafood Restaurant  42.363237 -71.056139
# 2               Sandwich Place  42.363292 -71.056068
# 3                  Comedy Club  42.362931 -71.055404
# 4                Deli / Bodega  42.363071 -71.055041
# ..                         ...        ...        ...
# 90                        Café  42.358467 -71.057648
# 91                  Ski Chalet  42.363679 -71.059239
# 92                 Coffee Shop  42.363144 -71.059830
# 93                        Park  42.361027 -71.051451
# 94  Tourist Information Center  42.360232 -71.052371
#
#                           id number of Italian Restaurants
# 0   4ba50617f964a520f1d138e3                            15
# 1   4ac53112f964a520dbb020e3                            15
# 2   4dea5487d164ef597ce79171                            15
# 3   40b28c80f964a520d5f71ee3                            15
# 4   53a74381498e34ef9a6217ea                            15
# ..                       ...                           ...
# 90  5bd8f4b4f709c1002cc147cd                             1
# 91  53dff5aa498e8db166762d66                             0
# 92  51a49c41498e034cea66e562                             0
# 93  4ae3580af964a520c59321e3                             0
# 94  4e340b82483b5fa58752a25a                             0
#
# [95 rows x 14 columns]

# %% [markdown]
# ## plotting the map

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
kclusters=3
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(map_frame['lat'], map_frame['lng'], map_frame['postalCode'], map_frame['Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
